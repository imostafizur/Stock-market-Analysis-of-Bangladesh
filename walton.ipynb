# %% [markdown]
# # Walton Stock Market Analysis

# %%
from keras.layers import LSTM, Dropout, Dense
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from matplotlib.pylab import rcParams
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

rcParams['figure.figsize'] = 20, 10

# %%
# load data
df = pd.read_csv('walton.csv')
df.head()
# Out:
#            Date     Price      Open      High       Low   Vol. Change %
# 0  Aug 22, 2022  1,056.70  1,060.30  1,061.90  1,055.00  4.93K   -0.06%
# 1  Aug 21, 2022  1,057.30  1,057.00  1,062.00  1,055.00  2.34K    0.07%
# 2  Aug 17, 2022  1,056.60  1,062.90  1,062.90  1,052.00  1.64K    0.71%
# 3  Aug 16, 2022  1,049.10  1,052.50  1,059.90  1,047.80  7.88K   -0.59%
# 4  Aug 14, 2022  1,055.30  1,051.10  1,057.00  1,049.00  3.38K    0.40%

# %%
# changing the date format all the dates are in the format of YYYY-MM-DD and take all columns as it is
from datetime import datetime, timedelta
df['Date'] = pd.to_datetime(df['Date'])
df['Date'] = df['Date'] + timedelta(days=1)
df['Date'] = df['Date'].dt.strftime('%Y-%m-%d')
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date     Price      Open      High       Low   Vol. Change %
# 0 2022-08-23  1,056.70  1,060.30  1,061.90  1,055.00  4.93K   -0.06%
# 1 2022-08-22  1,057.30  1,057.00  1,062.00  1,055.00  2.34K    0.07%
# 2 2022-08-18  1,056.60  1,062.90  1,062.90  1,052.00  1.64K    0.71%
# 3 2022-08-17  1,049.10  1,052.50  1,059.90  1,047.80  7.88K   -0.59%
# 4 2022-08-15  1,055.30  1,051.10  1,057.00  1,049.00  3.38K    0.40%

# %%
# Dataset size
df.shape
# Out:
# (459, 7)

# %%
# Null values
df.isnull().sum()
# Out:
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# dtype: int64

# %%
# Save the dataframe 
#df.to_csv('walton_Processed.csv', index=False)

# %%
# load data
df = pd.read_csv('walton_Processed.csv')
df.head()
# Out:
#          Date     Price      Open      High       Low   Vol. Change %
# 0  2022-08-23  1,056.70  1,060.30  1,061.90  1,055.00  4.93K   -0.06%
# 1  2022-08-22  1,057.30  1,057.00  1,062.00  1,055.00  2.34K    0.07%
# 2  2022-08-18  1,056.60  1,062.90  1,062.90  1,052.00  1.64K    0.71%
# 3  2022-08-17  1,049.10  1,052.50  1,059.90  1,047.80  7.88K   -0.59%
# 4  2022-08-15  1,055.30  1,051.10  1,057.00  1,049.00  3.38K    0.40%

# %%
# Describe the data
df.describe()
# Out:
#               Date     Price      Open      High       Low   Vol. Change %
# count          459       459       459       459       459    459      459
# unique         459       434       373       344       367    433      305
# top     2022-08-23  1,082.40  1,080.00  1,090.00  1,080.00  2.56K    7.50%
# freq             1         3         8         7         7      3        8

# %%
# Dataset size
df.shape
# Out:
# (459, 7)

# %%
#staring date
df['Date'].min()
# Out:
# '2020-09-25'

# %%
# ending date
df['Date'].max()
# Out:
# '2022-08-23'

# %%
# Plotting the data using iplot 
df.iplot(kind='scatter', x='Date', y='Price', title='Price vs Date')
# Out:
# <div>                            <div id="57a0d7fb-8df3-4490-bc8c-36c5d370ccd4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Creating a filled area chart
df.iplot(kind='scatter', x='Date', y='Change %', fill='green', title='Change % vs Date')
# Out:
# <div>                            <div id="765a47ac-e7f4-413d-9319-d67f18f90425" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = cf.QuantFig(single_stock, title='First Quant Figure',legend='top', name='GS')
df.add_sma([10, 20], width=2, color=['green', 'lightgreen'], legendgroup=True)
df.add_bollinger_bands()
df.add_volume()
df.iplot()
# Out:
# <div>                            <div id="702e9bea-2723-4cb2-8871-621430e2328a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
import matplotlib.pyplot as plt
df.Price.plot(figsize=(10, 5))
# Define the label for the title of the figure
plt.title("Close Price", fontsize=16)
# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Date', fontsize=14)
# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\mosta\Desktop\Mal\walton.ipynb Cell 18 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/mosta/Desktop/Mal/walton.ipynb#X54sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mosta/Desktop/Mal/walton.ipynb#X54sZmlsZQ%3D%3D?line=1'>2</a> df.Price.plot(figsize=(10, 5))
#       <a href='vscode-notebook-cell:/c%3A/Users/mosta/Desktop/Mal/walton.ipynb#X54sZmlsZQ%3D%3D?line=2'>3</a> # Define the label for the title of the figure
#       <a href='vscode-notebook-cell:/c%3A/Users/mosta/Desktop/Mal/walton.ipynb#X54sZmlsZQ%3D%3D?line=3'>4</a> plt.title("Close Price", fontsize=16)
#
# File c:\Users\mosta\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
# ...
